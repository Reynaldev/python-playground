# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.firefox.service import Service
from webdriver_manager.firefox import GeckoDriverManager

import time

# %%
element_list = []

options = webdriver.FirefoxOptions()
# options.add_argument("-headless")

service = Service(GeckoDriverManager().install())

# %%
# Initialize driver properly
driver = webdriver.Firefox(service=service, options=options)

# Load the URL
url = f"https://www.youtube.com/watch?v=qdfVsrpkOX4"
driver.get(url)
time.sleep(30)  # Optional wait to ensure page loads

# Extract product details
comments = driver.find_elements(By.ID, "content-text")

# Store results in a list
for i in range(len(comments)):
    element_list.append([
        comments[i].text,
    ])

driver.quit()

# %%
# Display extracted data
for row in element_list:
    print(row)
# Out:
# ['kalau ada yang ribet kenapa cari yang simpel']
# ['Moto adalah pelopor hp flip pertama di dunia,dari yg jadul sampe yg modern']
# ['Sebelum ke Gadgetin\nPasti selalu kesini dulu. Yg slalu update ']
# ['sayangnya kek motorola x50 ultra yg gk masuk resmi']
# ['Motorolla tampilannya lbh mewah.\n15 thn lalu pernah punya motorolla lipat V8 gold.']
# ['Bjorrr aku ngidam model slide gini mirip blackberry torch dan blackberry priv  akhirNya']
# ['Mantap jadi bernostalgia dengan blackberry']
# ['MANTAP']
# ['Siap2 nabung pengen beli']
# ['Spesifikasi Motorola RAZR 60 ultra itu jauh lebih bagus dibanding Samsung galaxy z flip 7, yang tadinya hanya ada untuk pasar China dan US. Bila masuk ke Indonesia pasti bisa mengalahkan z flip 7!']
# ['Tambah keyboard qwerty jadi premium banget tampilannya.']
# ['Pertama kali liat keyboard ini sekitar 3 bulan lalu, cuma ada buat razr dan iphone. Hari ini dibahas Dhiarcom, mantap, semuga di pasaran Indonesia bisa segera luncur.']
# ['cesing paling berguna sejauh ini']
# ['Kangen pake HP model keyboard Qwerty']
# ['Motorola agak lain kalau masalah aksesoris dan fitur. Bisa-bisanya teknologi jadul disatukan dengan teknologi baru yang lebih modern. The real tidak melupakan sejarah.']
# ['Ini baru inovasi']
# ['Jd ky BB Torch pas pake keyboard dalam kondisi terlipat ']
# ['Kapok sekapok kapok nya beli handheld mode flip ..\ndulu beli flip 3 sebaru-baru nya, lama kelamaan setelah update OS, muncul light saber segaris doang ..\n\nsemakin kesini, semakin nambah garis nya ..\nakhir nya sekarang pensiun flip nya, mau ganti lcd mehong ..\nmasih di angka 3rebu, mending beli hp baru daripada ganti lcd ']
# ['Accs keyboardnya lebih cocok untuk kondisi lipat, dipakai di layar kecilnya. Jadi lebih mirip BB. Dan juga memudahkan mengetik, karena di layar kecil agak susah ngetik pakai virtual keyboard. Kalau dipakai di layar lipatnya malah jadi aneh dan gak ergonomis, bisa keselip hapenya jatuh. Btw, secara overall Razr 60 Ultra bisa banget bersaing dengan hape lipat lain. Karena juga marketnya berbeda. Samsung dan Vivo lebih ke market yang elegan. Sedangkan Motorola Razr 60 Ultra lebih ke market fun dan power user. Kalau rilis di Indonesia, pasti aku beli, secara udah bosen dengan Samsung Flip, sejak Flip 3 sampai 7 sekarang. Oya, kalau di Samsung ada accs buat layar kecilnya, tapi lebih ke gimmick atau fun, bukan fungsional keyboard seperti accs di Moto Razr 60 Ultra ini.']
# ['Harusmya ada update software ga sih om? Biar pas klik mau ngetik ga keluar di layar duluan, kaya OneUI yang kalau ada S Pen, keyboard di layarnya ga keluar karna ngutamain S Pen yang stylus mode di layar']
